# %%
import numpy as np
from mldlsb.utils import visualize

# %%
test_seq = np.arange(-30,30,0.1)
visualize(seq=test_seq, function="sigmoid")
visualize(seq=test_seq, function="hyperbolic tangent", color="#BC8F8F")
visualize(seq=test_seq, function="relu", color="#DB7093")
visualize(seq=test_seq, function="leaky relu", color="#FF4500")
visualize(seq=test_seq, function="elu", color="#6A5ACD", a=1)
